# %%
# import necessary modules
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # Important functions

# %%
# to get Product title
def get_title(dom):
    try:
        title = dom.find('span',attrs={"id":"productTitle"}).contents[0].strip()
    except:
        title = ''
    
    return title 


# to get Product price
def get_price(dom):
    try:
        price = dom.find('span',attrs={"class":"a-price-whole"}).contents[0].strip()
    except:
        price = ''
    
    return price

# to get Product ratings
def get_ratings(dom):
    try:
        ratings = dom.find('span',attrs={"class":"a-size-medium a-color-base"}).contents[0].strip() + ' stars'
    except:
        ratings = ''
    
    return ratings 

# to get no_of_reviews
def get_no_of_reviews(dom):
    try:
        reviews = dom.find('span',attrs={"id":"acrCustomerReviewText"}).contents[0].strip()
    except:
        reviews = ''
    
    return reviews 

# to get Product availability
def get_availability(dom):
    try:
        available = dom.find('span',attrs={"class":"a-size-medium a-color-success"}).contents[0].strip()
    except:
        available = ''
    
    return available

# %% [markdown]
# # Main Code to extract data

# %%
# params
URl = "https://www.amazon.in/s?k=playstation+5&crid=187H30T6PFLVZ&sprefix=playstation+%2Caps%2C198&ref=nb_sb_ss_ts-doa-p_1_12"
Headers = {'User-Agent':
               'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:108.0) Gecko/20100101 Firefox/108.0',
           'Accept-Language':'en-US,en;q=0.5'
          }

# %%
# http get request
resp_obj = requests.get(URl , headers=Headers)

# %%
type(resp_obj.content)
# Out:
# bytes

# %%
type(resp_obj.text)
# Out:
# str

# %%
# beautiful soup object
soup = BeautifulSoup(resp_obj.text,'html.parser')

# %%
# find all anchor tag
links = soup.find_all('a',attrs={"class": "a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"})

# %%
data = {'Product_title':[],
        'Price(Rs)':[],
        'Rating_stars':[],
        'No_of_review':[],
        'Available':[]}
for link in links:
    half_url = link.get('href')
    new_url = 'https://amazon.in/' + half_url
    resp_obj = requests.get(new_url , headers=Headers)
    dom = BeautifulSoup(resp_obj.text,'html.parser')
    data['Product_title'].append(get_title(dom))
    data['Price(Rs)'].append(get_price(dom))
    data['Rating_stars'].append(get_ratings(dom))
    data['No_of_review'].append(get_no_of_reviews(dom))
    data['Available'].append(get_availability(dom))

# %%
df = pd.DataFrame(data)

# %%
import numpy as np
df.replace('',np.nan,inplace=True)

# %%
df
# Out:
#                                         Product_title Price(Rs)  \
# 0   God Of War Ragnarok | Launch Edition | PS5 Gam...     4,999
# 1   Sonic Frontiers | Standard Edition | PlayStati...     3,499
# 2                              PS5 Grand Theft Auto V     2,099
# 3   PlayStation 5 – The Best Hidden Features and E...       221
# 4   Need For Speed Unbound | Standard Edition | Pl...     4,438
# 5                                        PS5 WWE 2K22     1,999
# 6   Horizon Forbidden West | Standard Edition | PS...     2,683
# 7   Sony DualSense Wireless Controller for PlaySta...     5,098
# 8   Gran Turismo 7 | Standard Edition | PS5 Game (...     2,697
# 9   CRASOME Dust Cover for PS5 Lining Dust Guard f...       298
# 10                                       PS5 WWE 2K22     1,999
# 11   FIFA 23 | Standard Edition | PS5 (PlayStation 5)     3,909
# 12  Marvel's Midnight Suns | Enhanced Edition | Pl...     4,122
# 13      Sony Marvel's Spider-Man: Miles Morales (PS5)     2,099
# 14  Blackpoll Water Proof Dust Cover for PS5 Conso...       299
# 15  DualSense Wireless Controller Red (PlayStation 5)     5,399
# 16  Michael Schumacher PX1 Car Steering and padals...       NaN
# 17        DualSense Charging Station - (PlayStation5)     2,499
# 18  WALLTON - PS5 Skin Protective Wrap Cover Vinyl...       899
# 19  SKIN POSTER - PS5 Skin Protective Vinyl Sticke...       799
# 20  SKIN POSTER - PS5 Skin Protective Vinyl Sticke...       799
# 21  Skin Poster - PS5 Skin Protective Vinyl Sticke...       798
#
#           Rating_stars   No_of_review              Available
# 0   4.6 out of 5 stars    110 ratings              In stock.
# 1     5 out of 5 stars       1 rating              In stock.
# 2   4.4 out of 5 stars    104 ratings              In stock.
# 3     2 out of 5 stars       1 rating                    NaN
# 4   4.1 out of 5 stars      2 ratings              In stock.
# 5   4.2 out of 5 stars     58 ratings              In stock.
# 6   4.6 out of 5 stars    210 ratings              In stock.
# 7   4.4 out of 5 stars  1,305 ratings              In stock.
# 8   4.1 out of 5 stars    122 ratings              In stock.
# 9   4.5 out of 5 stars      2 ratings              In stock.
# 10  4.2 out of 5 stars     58 ratings              In stock.
# 11  4.5 out of 5 stars     44 ratings              In stock.
# 12                 NaN            NaN  Only 2 left in stock.
# 13  4.5 out of 5 stars    500 ratings              In stock.
# 14  4.1 out of 5 stars     20 ratings              In stock.
# 15  4.5 out of 5 stars    385 ratings              In stock.
# 16                 NaN            NaN                    NaN
# 17  4.7 out of 5 stars    306 ratings              In stock.
# 18  2.9 out of 5 stars      3 ratings              In stock.
# 19  3.7 out of 5 stars      3 ratings              In stock.
# 20                 NaN            NaN              In stock.
# 21    1 out of 5 stars       1 rating              In stock.

# %% [markdown]
# saving dataframe in csv format

# %%
df.to_csv('./Scraped_data_from_amazon.csv',header=True,index=False)
